# %% [markdown]
# # Tests for Cost Estimation Utilities
#
# _Last Update:_ 2025.11.08

# %% [markdown]
# ## Environmental Settings

# %%
import os
import sys
from pathlib import Path
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# PROJECT ROOT to Python paths
ROOT_DIR = Path().resolve().parents[0]
if str(ROOT_DIR) not in sys.path:
    sys.path.insert(0, str(ROOT_DIR))
# RELOAD the custom script
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from dotenv import load_dotenv
# Load environment variables from .env file
SECRETS_FILE = Path(r"C:\LocalSecrets\master.env")
load_dotenv(str(SECRETS_FILE))
# ASSIGN the values of the environment variables
openai_key = str(os.getenv("OPENAI_UIO24EMC_KEY"))
pplx_key = str(os.getenv("PERPLEXITY_UIO24EMC_KEY"))
claude_key = str(os.getenv("ANTHROPIC_API_KEY"))

# %% [markdown]
# ## Estimation Utilities
# - `estimate_costs_for_models()`: Calculate token usage and costs for DataFrame inputs
# - `create_cost_matrix()`: Format cost estimates into styled comparison tables
# - `display_gpt_models_df()`: Display OpenAI model pricing and token limits

# %%
# 01 Basic View of Cost per 1$ per 1 Million Tokens input and Output
from gptquery.estimation.cost_estimator import display_gpt_models_df
display_gpt_models_df()
# Out:
#                     Model  Max Input Tokens  Max Output Tokens  \
# 20          gpt-3.5-turbo           16385.0             4096.0
# 24     gpt-3.5-turbo-0125           16385.0             4096.0
# 21     gpt-3.5-turbo-0301            4097.0             4096.0
# 22     gpt-3.5-turbo-0613            4097.0             4096.0
# 23     gpt-3.5-turbo-1106           16385.0             4096.0
# ..                    ...               ...                ...
# 57             gpt-5-mini          400000.0           128000.0
# 62  gpt-5-mini-2025-08-07          400000.0           128000.0
# 58             gpt-5-nano          400000.0           128000.0
# 63  gpt-5-nano-2025-08-07          400000.0           128000.0
# 49            gpt-image-1               NaN                NaN
#
#    Input Cost ($/1M) Output Cost ($/1M)
# 20            $1.500             $2.000
# 24            $0.500             $1.500
# 21            $1.500             $2.000
# 22            $1.500             $2.000
# 23            $1.000             $2.000
# ..               ...                ...
# 57            $0.250             $2.000
# 62            $0.250             $2.000
# 58            $0.050             $0.400
# 63            $0.050             $0.400
# 49            $0.000             $0.000
#
# [64 rows x 5 columns]

# %%
# IMPROT Functions
from gptquery.estimation.cost_estimator import (estimate_costs_for_models)
from gptquery.tools.tool_eulaw_citations.validate_citations.prompts.default import (prompt_validate_completeness,
                                                                                    VALIDATION_SYSTEM_MESSAGE)
# LOAD reliability CSV
df_reliab = pd.read_csv(ROOT_DIR / "data" / "uio24hlp" / "realiability_data_refs.csv")
df_ref_lvl = df_reliab[["uoa_referral_id",
                        "questions_text", 
                        "std_potential_citations",
                        "nlang_potential_citations"]].drop_duplicates().reset_index(drop=True)

# RENAME columns so thet match prompt fucntion @required_columns() decorator.
df_ref_lvl = df_ref_lvl.rename(columns={"questions_text": "question_text"})                   # type: ignore
df_ref_lvl = df_ref_lvl.rename(columns={"nlang_potential_citations": "potential_citations"})  # type: ignore

# MODELS to tests
MODELS = ["gpt-4.1-mini", "gpt-5", "gpt-5-mini","gpt-5-nano" ]

# COST estimation
costs = estimate_costs_for_models(df_ref_lvl,
                                  prompt_validate_completeness,
                                  models=MODELS,
                                  system_msg=VALIDATION_SYSTEM_MESSAGE,
                                  expected_response_length= "completed")

# %%
## 03 TEST COST MATRIX
from gptquery.estimation.cost_estimator import (create_cost_matrix)
create_cost_matrix(costs)
# Out:
# <style type="text/css">
# #T_a8565_row0_col1 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_a8565_row1_col1 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_a8565_row2_col1 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_a8565_row3_col1 {
#   background-color: #fee28f;
#   color: #000000;
# }
# </style>
# <table id="T_a8565">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8565_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a8565_level0_col1" class="col_heading level0 col1" >Total Cost ($)</th>
#       <th id="T_a8565_level0_col2" class="col_heading level0 col2" >Cost Per Row ($)</th>
#       <th id="T_a8565_level0_col3" class="col_heading level0 col3" >Total Tokens</th>
#       <th id="T_a8565_level0_col4" class="col_heading level0 col4" >Input Cost ($)</th>
#       <th id="T_a8565_level0_col5" class="col_heading level0 col5" >Output Cost ($)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8565_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8565_row0_col0" class="data row0 col0" >gpt-5-nano</td>
#       <td id="T_a8565_row0_col1" class="data row0 col1" >$0.3699</td>
#       <td id="T_a8565_row0_col2" class="data row0 col2" >$0.0001</td>
#       <td id="T_a8565_row0_col3" class="data row0 col3" >7,358,179</td>
#       <td id="T_a8565_row0_col4" class="data row0 col4" >$0.3679</td>
#       <td id="T_a8565_row0_col5" class="data row0 col5" >$0.0020</td>
#     </tr>
#     <tr>
#       <th id="T_a8565_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a8565_row1_col0" class="data row1 col0" >gpt-5-mini</td>
#       <td id="T_a8565_row1_col1" class="data row1 col1" >$1.8496</td>
#       <td id="T_a8565_row1_col2" class="data row1 col2" >$0.0004</td>
#       <td id="T_a8565_row1_col3" class="data row1 col3" >7,358,179</td>
#       <td id="T_a8565_row1_col4" class="data row1 col4" >$1.8395</td>
#       <td id="T_a8565_row1_col5" class="data row1 col5" >$0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_a8565_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a8565_row2_col0" class="data row2 col0" >gpt-4.1-mini</td>
#       <td id="T_a8565_row2_col1" class="data row2 col1" >$2.9513</td>
#       <td id="T_a8565_row2_col2" class="data row2 col2" >$0.0006</td>
#       <td id="T_a8565_row2_col3" class="data row2 col3" >7,358,179</td>
#       <td id="T_a8565_row2_col4" class="data row2 col4" >$2.9433</td>
#       <td id="T_a8565_row2_col5" class="data row2 col5" >$0.0080</td>
#     </tr>
#     <tr>
#       <th id="T_a8565_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a8565_row3_col0" class="data row3 col0" >gpt-5</td>
#       <td id="T_a8565_row3_col1" class="data row3 col1" >$9.2480</td>
#       <td id="T_a8565_row3_col2" class="data row3 col2" >$0.0018</td>
#       <td id="T_a8565_row3_col3" class="data row3 col3" >7,358,179</td>
#       <td id="T_a8565_row3_col4" class="data row3 col4" >$9.1977</td>
#       <td id="T_a8565_row3_col5" class="data row3 col5" >$0.0502</td>
#     </tr>
#   </tbody>
# </table>
